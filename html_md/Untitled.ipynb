# %%
import os
fns = [x for x in os.listdir(".") if os.path.isdir(x) is True]
for fn in fns:
    index = os.path.join(fn, 'index.html')
    if os.path.exists(index):
        print "mv",index, fn+"/"+fn+".html"
# Out:
# mv 200mph-ferrari-california-launched-buyers-not-greedy-show-offs-just-vulnerable-fragile-big-infants-in-need-of-affection/index.html 200mph-ferrari-california-launched-buyers-not-greedy-show-offs-just-vulnerable-fragile-big-infants-in-need-of-affection/200mph-ferrari-california-launched-buyers-not-greedy-show-offs-just-vulnerable-fragile-big-infants-in-need-of-affection.html
# mv a-brief-philosophy-of-oral-sex/index.html a-brief-philosophy-of-oral-sex/a-brief-philosophy-of-oral-sex.html
# mv a-colourful-seductive-church-in-southern-germany-offers-the-guardian-a-lesson/index.html a-colourful-seductive-church-in-southern-germany-offers-the-guardian-a-lesson/a-colourful-seductive-church-in-southern-germany-offers-the-guardian-a-lesson.html
# mv a-guide-to-the-pleasures-of-work/index.html a-guide-to-the-pleasures-of-work/a-guide-to-the-pleasures-of-work.html
# mv a-lovers-guide-to-sulking/index.html a-lovers-guide-to-sulking/a-lovers-guide-to-sulking.html
# ...
